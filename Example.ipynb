# %%
from Expresssion2RGB import Expression2Img
from utils import PathHandler, VisiumPaths
import cv2
import matplotlib.pyplot as plt

# %%
visium_dir="/sdd/MOB/new_data/V19D02-086_A1/"

# %%
h5_path = f"{visium_dir}{VisiumPaths.h5_path}"
spatial_path = f"{visium_dir}{VisiumPaths.spatial_path}"
scale_factor_path = f"{visium_dir}{VisiumPaths.scale_factor_path}"

# %%
E2I = Expression2Img(h5_path, spatial_path, scale_factor_path)

# %%
hi_img = E2I.getImage(zdim=256, PEalpha=0.5)
# Out:
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# ---- Load data ----
#   0%|                                                                        | 0/500 [00:00<?, ?it/s]
# After preprocessing, 13149 genes remaining
# After preprocessing, 824 cells have 0.99 nonzero
# ---- Reduce dimensions ----
# 100%|██████████████████████████████████████████████████████████████| 500/500 [00:45<00:00, 10.92it/s]
#   0%|                                                                        | 0/200 [00:00<?, ?it/s]
# ---- Get GAE embedding ----
# 100%|█████████████████████████████████████████████████████████████| 200/200 [00:01<00:00, 126.68it/s]
# ---- Convert embedding to image ----

# %%
img = cv2.imread('/sdd/RESEPT/Demo_result1/RGB_images/V19D02-086_A1_scGNN_logcpm_PEalpha0.5_zdim256.png')

# %%
fig = plt.figure(figsize=(15,15))
ax1 = fig.add_subplot(121)
plt.imshow(hi_img),plt.title('Expression2RGB')

ax2 = fig.add_subplot(122)
plt.imshow(img),plt.title('RESEPT')
# Out:
# (<matplotlib.image.AxesImage at 0x7f6245d3e3d0>, Text(0.5, 1.0, 'RESEPT'))
